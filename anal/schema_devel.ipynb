# %%
import json
import itertools
from collections import Counter

import fuzzysearch
from genson import SchemaBuilder
from typing import Dict

# %% [markdown]
# ### Load the raw data

# %%
# would really like to use pandas, but it doesn't really support nested data
# so I invented stuff myself
with open("raw_companies.json") as f:
    raw_companies = json.load(f)

# %% [markdown]
# ### Print all the top-level keys

# %%
company: dict
top_level_keys = set(itertools.chain(*(company.keys() for company in raw_companies)))

print(*sorted(top_level_keys), sep='\n')
# Out:
# antalAnsatte
# ejerforhold
# foreningsrepraesentanter
# harManuelSignering
# historiskStamdata
# hovedselskab
# oplysningerOmRevisionsvirksomhed
# personkreds
# produktionsenheder
# sammenhaengendeRegnskaber
# skjulOevrigeDokumenter
# stamdata
# udvidedeOplysninger
# virksomhedRegistreringer
# virksomhedsMeddelelser

# %% [markdown]
# It's all in Danish!

# %%
# just a cell for looking at various fields
# I use PyCharm to view it
test = [ c['antalAnsatte'] for c in raw_companies]

# %% [markdown]
# ### Load the pre-downloaded translations

# %%
# oh wow, they have the translations on the site!
# though it might be not so easy to interpret
with open('raw_translations.json') as f:
    raw_translations = json.load(f)

# filter to include only the english ones
raw_translations = [t for t in raw_translations if t['locale'] == 'en']

# convert to an easily-searchable form
raw_translations_text = []
for trans in raw_translations:
    assert trans['type'] == 'Text'
    raw_translations_text.append(f"{trans['code']:100}: {trans['message']}")

# write it out
with open('en_translations.txt', 'w') as f:
    f.write('\n'.join(raw_translations_text))

# %%
def collect_keys(obj):
    """
    Collect all the JSON keys used in the document
    """
    ty = type(obj)
    if ty is list:
        return Counter(itertools.chain(*(collect_keys(obj) for obj in obj)))
    elif ty is dict:
        obj: dict
        res = Counter()
        for k, v in obj.items():
            res[k] += 1
            res |= collect_keys(v)
        return res

    elif ty in [str, int, bool, float, type(None)]:
        return Counter()
    else:
        raise RuntimeError(f"Don't know how to handle type {ty}")

# %% [markdown]
# ### Define the mapping from the danish names to English

# %%
# mostly based on google translate and common sense
translations = {
    'antalAnsatte':             'number_of_employees',
    'ejerforhold':              'ownership',
    'foreningsrepraesentanter': 'association_representatives', # like a person that can operate in the name of the company?
    'harManuelSignering':       'has_manual_signing', # a boolean, so prolly like a confirmation?

    'stamdata':             'basic_data', # master data seems to be the main info about the company
    'historiskStamdata':    'historic_basic_data', # old values of the master data

    'hovedselskab':                         'parent_company',
    'oplysningerOmRevisionsvirksomhed':     'information_about_auditing',
    'personkreds':                          'circle_of_people', # maybe line contacts? Or just people connected to the company?
    'produktionsenheder':                   'production_units',
    'sammenhaengendeRegnskaber':            'coherent_accounts',
    'skjulOevrigeDokumenter':               'hide_other_documents',
    'udvidedeOplysninger':                  'extended_information',
    'virksomhedRegistreringer':             'company_registrations',
    'virksomhedsMeddelelser':               'company_announcements',

    'adresse': 'address',
    'aktiveLegaleEjere':    'active_legal_owners',
    'aktiveReelleEjere':    'active_beneficial_owners',
    'formaal':              'purpose', # seems like a mission statement or smth
    'virksomhedsform':      'bussiness_type',

    'hovedbranche':     'main_industry',
    'bibrancher':       'additional_industries',
    'branchekode':      'industry_code',
    'titel':            'title',
    'bibranche':        'additional_industries',

    'navn':                         'name',
    'ophoerteLegaleEjere':          'terminated_legal_owners',
    'begunstigetGruppeNavn':        'beneficiary_group_name',
    'begunstigetGruppeRetskrav':    'beneficiary_group_legal_claim',
    'status':                       'status',
    'email':                        'email',
    'pnummer':                      'p_number', # some domain-specific identifier?
    'cvrnummer':                    'cvr_number',
    'ophoersdato':                  'cessation_date',
    'regnummer':                    'registration_number',
    'telefon':                      'telephone',
    'startdato':                    'start_date',
    'virksomhedsnavn':              'company_name',
    'binavne':                      'secondary_names',
    'reklamebeskyttet':             'advertising_protection',
}

# %% [markdown]
# ### Print the missing translations with candidates found via fuzzy search

# %%
keys = collect_keys(raw_companies)

print("Missing translations:\n")
untranslated_count = 0
for k, count in keys.most_common():
    if k not in translations:
        untranslated_count += 1

        # emitting too much info is not really convienent
        if untranslated_count < 40:
            print(f"{k:70} ({count} counts)")

            # search for possible candidates in the raw_translations_text

            r = []
            if len(k) > 4:
                for text in raw_translations_text:
                    if fuzzysearch.find_near_matches(k, text, max_l_dist=4):
                        r.append(text)

            if r:
                print(*r, sep='\n')
            print()

print(f"\nIn total {untranslated_count} untranslated keys")
# Out:
# Missing translations:
#
# kvartalsbeskaeftigelse                                                 (1578 counts)
#
# maanedsbeskaeftigelse                                                  (1578 counts)
#
# bestyrelseAnsesSomReelleEjere                                          (1578 counts)
#
# ejerregistreringUnderFemProcent                                        (1578 counts)
#
# ophoerteReelleEjere                                                    (1578 counts)
# soeg-filter-personrolle-ophoert_reelle_ejere-label                                                  : Beneficial owners
# ejerforhold-ophoerte-reelle-ejere-label                                                             : Terminated beneficial owners
#
# virksomhedHarIkkeKunnetIdentificereReelleEjereLedelseErIndsat          (1578 counts)
#
# virksomhedHarIkkeReelleEjereOgLedelseErIndsat                          (1578 counts)
#
# registreretKapital                                                     (1578 counts)
# historisk-stamdata-registreret_kapital-tabel-overskrift                                             : Registered capital
# historisk-stamdata-registreret_kapital-tabel-label-gyldigFra                                        : From
# historisk-stamdata-registreret_kapital-tabel-label-gyldigTil                                        : Till
# historisk-stamdata-registreret_kapital-tabel-label-vaerdi                                           : Value
# udvidede_oplysninger-registreretKapital-label                                                       : Registered capital
#
# senesteVedtaegtsdato                                                   (1578 counts)
# historisk-stamdata-seneste_vedtaegtsdato-tabel-overskrift                                           : Latest articles of association
# historisk-stamdata-seneste_vedtaegtsdato-tabel-label-gyldigFra                                      : From
# historisk-stamdata-seneste_vedtaegtsdato-tabel-label-gyldigTil                                      : Till
# historisk-stamdata-seneste_vedtaegtsdato-tabel-label-vaerdi                                         : Value
# udvidede_oplysninger-seneste_vedtaegtsdato-label                                                    : Latest articles of association
# udvidede_oplysninger-seneste_vedtaegtsdato_foer-1900-label                                          : Before 1900
#
# tegningsregel                                                          (1578 counts)
# personkreds-tegningsregel-label                                                                     : Powers to bind
# virksomhed-hovedselskab-tegningsberettiget                                                          : Empowered to sign
# virksomhed-hovedselskab-tegningsregel                                                               : Power to bind
# historisk-stamdata-tegningsregel-tabel-overskrift                                                   : Powers to bind
# historisk-stamdata-tegningsregel-tabel-label-gyldigFra                                              : From
# historisk-stamdata-tegningsregel-tabel-label-gyldigTil                                              : Till
# historisk-stamdata-tegningsregel-tabel-label-vaerdi                                                 : Value
# notifikationstype-personkreds-og-tegningsregel                                                      : Key individuals and power to bind
#
# udenlandskAdresse                                                      (1578 counts)
# stamdata-udenlandsk_adresse-label                                                                   : Foreign address
# historisk-stamdata-udenlandsk_adresse-tabel-label-gyldigFra                                         : From
# historisk-stamdata-udenlandsk_adresse-tabel-label-gyldigTil                                         : Till
# historisk-stamdata-udenlandsk_adresse-tabel-overskrift                                              : Foreign address
# historisk-stamdata-udenlandsk_adresse-tabel-label-vaerdi                                            : Value
#
# ejerborgLink                                                           (1578 counts)
#
# personkredser                                                          (1578 counts)
# accordion-personkreds-overskrift                                                                    : Power to bind, key individuals and auditor
# personkreds-tegningsregel-label                                                                     : Powers to bind
# notifikationstype-personkreds-og-tegningsregel                                                      : Key individuals and power to bind
# personkreds-suppleantfor-label                                                                      : Alternate for:
# personkreds-udnaevntaf-label                                                                        : Appointed by:
# personkreds-valgform-label                                                                          : Election procedure:
# accordion-personkreds-hjaelp-overskrift                                                             : Power to bind, key individuals and auditor
# accordion-personkreds-hjaelp-indhold                                                                : <p>&lt;strong&gt;Power to bind the company&lt;/strong&gt; &lt;br/&gt;<br/>The provisions regarding the power to bind the company indicate who may make contracts on behalf of the company.&lt;br/&gt;</p><p>Sole proprietorships and other personally owned companies do not have any such provisions. The persons who bind a personally owned company are always the fully liable partners (or partner).&lt;br/&gt;</p><p>&lt;strong&gt;Fully liable partner&lt;/strong&gt; &lt;br/&gt;<br/>A fully liable partner owns a personally owned company. Some company types have several fully liable partners. They are personally, jointly and severally liable. &lt;br/&gt;</p><p>&lt;strong&gt;Management&lt;/strong&gt; &lt;br/&gt;<br/>The management is responsible for the day-to-day management of the company. If the company is managed by the management alone, the management is also responsible for the overall and strategic management of the company.&lt;br/&gt;</p><p>&lt;strong&gt;Board of Directors&lt;/strong&gt; &lt;br/&gt;<br/>The Board of Directors is responsible for the overall and strategic management of the company. &lt;br/&gt;</p><p>&lt;strong&gt;Supervisory Board&lt;/strong&gt; &lt;br/&gt;<br/>The Supervisory Board may supervise the management if it has been decided not to have a Board of Directors.&lt;br/&gt;</p><p>&lt;strong&gt;Founders&lt;/strong&gt; &lt;br/&gt;</p><p>The founders decided to found the company.&lt;br/&gt;</p><p>&lt;strong&gt;Auditor&lt;/strong&gt; &lt;br/&gt;</p><p>The auditor is the person appointed to audit the company's annual report.</p>
#
# aktiveProduktionsenheder                                               (1578 counts)
#
# ophoerteProduktionsenheder                                             (1578 counts)
#
# bygningsnummer                                                         (1578 counts)
# stamdata-bygningsnummer-label                                                                       : B-number
#
# postnummerOgBy                                                         (1578 counts)
# stamdata-postnummerby-label                                                                         : Postal code and city
# postnummer-fejlmeddelelse-label                                                                     : Unknown postal code
#
# udenlandskAdresseLand                                                  (1578 counts)
#
# udenlandskAdresseLandekode                                             (1578 counts)
#
# aktiviteterOmfattetAfHvidvaskloven                                     (1578 counts)
#
# enhedsnummer                                                           (1578 counts)
# person-liberale_erhverv-mnenummer-label                                                             : Identification
# stamdata-bygningsnummer-label                                                                       : B-number
#
# harPseudoCvr                                                           (1578 counts)
#
# kreditoplysningskode                                                   (1578 counts)
# stamdata-kreditoplysninger-label                                                                    : Credit information
#
# modervirksomhederVedFranchise                                          (1578 counts)
#
# omfattetAfHvidvaskloven                                                (1578 counts)
# stamdata-aktiviteter_omfattet_af_hvidvaskloven-label                                                : Registered activities cf. the Anti-Money Laundering Act
# stamdata-omfattet_af_hvidvaskloven-label                                                            : Registered cf. the Anti-Money Laundering Act
#
# socialoekonomiskVirksomhed                                             (1578 counts)
# stamdata-socialoekonomisk_virksomhed-label                                                          : Social enterprise
# soeg-filter-virksomhedsmarkering-social_oekonomisk_virksomhed-label                                 : Registered social enterprise
#
# statsligVirksomhed                                                     (1578 counts)
# stamdata-statslig_virksomhed-label                                                                  : Government enterprise
#
# stiftetFor1900Tekstnogle                                               (1578 counts)
#
# virkningsdato                                                          (1578 counts)
# ejerandel-aendringsdato-label                                                                       : Date of change:
# person-liberale_erhverv-deponeringsdato-label                                                       : Date of deposit
# stamdata-virkningsdato-label                                                                        : Effective date
#
# virksomhedsformKode                                                    (1578 counts)
# historisk-stamdata-virksomhedsform-tabel-overskrift                                                 : Business type
# historisk-stamdata-virksomhedsform-tabel-label-gyldigFra                                            : From
# historisk-stamdata-virksomhedsform-tabel-label-gyldigTil                                            : Till
# historisk-stamdata-virksomhedsform-tabel-label-vaerdi                                               : Value
# forside-soegefelt-filter-virksomhedsform-label                                                      : Business type
# soegeresultater-tabel-virksomhedsform-label                                                         : Business type:
# stamdata-virksomhedsform-label                                                                      :  Business type
#
# visNavnPostfix                                                         (1578 counts)
#
# boersnoteret                                                           (1578 counts)
# soeg-filter-virksomhedsmarkering-boersnoteret-label                                                 : Listed company
# udvidede_oplysninger-boersnoteret-label                                                             : Listed
#
# delvistIndbetaltKapital                                                (1578 counts)
#
# fax                                                                    (1578 counts)
#
# foersteRegnskabsperiodeSlut                                            (1578 counts)
#
# foersteRegnskabsperiodeStart                                           (1578 counts)
#
# kapitalklasser                                                         (1578 counts)
# udvidede_oplysninger-kapitalklasser-label                                                           : Classes of shares
# ejerandel-kapitalklasse-label                                                                       : Class of shares:
#
# kommune                                                                (1578 counts)
# stamdata-statslig_virksomhed-label                                                                  : Government enterprise
# stamdata-socialoekonomisk_virksomhed-label                                                          : Social enterprise
# accordion-udvidede_virksomhedsoplysninger-hjaelp-overskrift                                         : Expanded business information
# accordion-udvidede_virksomhedsoplysninger-overskrift                                                : Expanded business information
# virksomhed-erhvervsstyrelsens_signatur-label                                                        : Signature of the Danish Business Authority
# virksomhed-foelg_virksomhed-label                                                                   : Follow company
# stamdata-cvrnummer-label                                                                            :  CVR number
# erstdist-organisation-rolle-registret_til_bekaempelse_af_hvidvask                                   : Persons in the Register for combating Money Laundering
# erstdist-organisation-rolle-stiftere                                                                : Founders
# soeg-filter-virksomhedsmarkering-social_oekonomisk_virksomhed-label                                 : Registered social enterprise
# soeg-filter-virksomhedsmarkering-helligdagsaabent-label                                             : Open on public holidays
# soeg-filter-virksomhedsmarkering-med_reklamebeskyttelse-label                                       : With advertising protection
# soeg-filter-virksomhedsmarkering-uden_reklamebeskyttelse-label                                      : Without advertising protection
# soeg-filter-virksomhedsmarkering-revisionsvirksomheder-label                                        : Audit firms
# soeg-filter-virksomhedsmarkering-boersnoteret-label                                                 : Listed company
# soeg-filter-virksomhedsmarkering-omfattet_af_lov_om_hvidvask_og_terrorfinansiering-label            : Registered cf. the Anti-Money Laundering Act
# soeg-filter-virksomhedsmarkering-paragraf17_stk1-label                                              : Article 17 audit firms
# soeg-filter-virksomhedsmarkering-registreret-label                                                  : Firms of Registered Public Accountants
# soeg-filter-virksomhedsmarkering-statsautoriseret-label                                             : Firms of State-Authorised Public Accountants
# soeg-filter-virksomhedsmarkering-tredjelands_godkendt-label                                         : Audit firms approved in third countries
# soeg-filter-virksomhedsmarkering-godkendt-label                                                     : Approved audit firms
# soeg-filter-virksomhedsmarkering-statslig_virk-label                                                : Government-owned limited company
# soeg-filter-virksomhedsstatus-undertvangsopløsning-label                                            : Under compulsory dissolution
# soeg-filter-virksomhedsstatus-underfrivilliglikvidation-label                                       : Under voluntary liquidation
# soeg-filter-virksomhedsstatus-oploesteftergraenseoverskridendespaltning-label                       : Dissolved after cross-border division
# soeg-filter-virksomhedsstatus-aktive-label                                                          : Active
# soeg-filter-virksomhedsstatus-underreassumering-label                                               : Under resumed proceedings
# soeg-filter-virksomhedsstatus-underkonkurs-label                                                    : Under bankruptcy proceedings
# soeg-filter-virksomhedsstatus-undertvangsoploesning-label                                           : Under compulsory dissolution
# soeg-filter-virksomhedsstatus-underrekonstruktion-label                                             : Under reconstruction
# soeg-filter-virksomhedsstatus-normal-label                                                          : Normal
# soeg-filter-virksomhedsstatus-aktiv-label                                                           : Active
# soeg-filter-virksomhedsstatus-omdannet-label                                                        : Converted
# soeg-filter-virksomhedsstatus-ophoerte-label                                                        : Terminated
# soeg-filter-virksomhedsstatus-ophoert-label                                                         : Dissolved
# soeg-filter-virksomhedsstatus-slettet-label                                                         : Deleted
# soeg-filter-virksomhedsstatus-oploestefterkonkurs-label                                             : Dissolved following bankruptcy
# soeg-filter-virksomhedsstatus-oploestefterfusion-label                                              : Dissolved following merger
# soeg-filter-virksomhedsstatus-oploestefterfrivilliglikvidation-label                                : Dissolved following voluntary liquidation
# soeg-filter-virksomhedsstatus-oploesteftererklaering-label                                          : Dissolved following declaration
# soeg-filter-virksomhedsstatus-tvangsoploest-label                                                   : Dissolved following compulsory dissolution
# soeg-filter-virksomhedsstatus-oploestefterspaltning-label                                           : Dissolved following demerger
# soeg-filter-virksomhedsstatus-oploesteftergraenseoverskridendefusion-label                          : Dissolved after cross-border merger
# soeg-filter-virksomhedsstatus-oploesteftergraenseoverskridendehjemstedsflytning-label               : Dissolved after cross-border conversion
# soeg-filter-personrolle-aktiv_stiftere-label                                                        : Founders
# soeg-filter-personrolle-aktiv_legale_ejere-label                                                    : Legal owners
# soeg-filter-personrolle-aktiv_reelle_ejere-label                                                    : Beneficial owners
# soeg-filter-personrolle-aktiv_hvidvask-label                                                        : Registered cf. the Anti-Money Laundering Act
# soeg-filter-personrolle-aktiv_ejendomsmaegler-label                                                 : Estate agent
# soeg-filter-personrolle-aktiv_revisor_statsautoriseret-label                                        : State-Authorised Public Accountant
# soeg-filter-personrolle-aktiv_revisor_registreret-label                                             : Registered Public Accountant
# soeg-filter-personrolle-ophoert_stiftere-label                                                      : Founders
# soeg-filter-personrolle-ophoert_legale_ejere-label                                                  : Legal owners
# soeg-filter-personrolle-ophoert_reelle_ejere-label                                                  : Beneficial owners
# soeg-filter-personrolle-ophoert_hvidvask-label                                                      : Registered cf. the Anti-Money Laundering Act
# soeg-filter-personrolle-ophoert_ejendomsmaegler-label                                               : Estate agent
# soeg-filter-personrolle-ophoert_revisor_statsautoriseret-label                                      : State-Authorised Public Accountant
# soeg-filter-personrolle-ophoert_revisor_registreret-label                                           : Registered Public Accountant
# broedkrumme-forside                                                                                 : Front page
# accordion-offentliggoerelser-hjaelp-indhold                                                         : <p>Get a list of announcements and invitations to general meetings from the business. You can download and save these to your computer.</p>
# accordion-offentliggoerelser-hjaelp-overskrift                                                      : Announcements
# accordion-offentliggoerelser-overskrift                                                             : Announcements
# virksomhed-offentliggoerelser-inner-overskrift                                                      : Announcements and notices
# virksomhed-offentliggoerelser-offentliggjort                                                        : Announced
# virksomhed-offentliggoerelser-handling                                                              : Action
# virksomhed-offentliggoerelser-visalle-lukket                                                        : Show all
# virksomhed-offentliggoerelser-visalle-aaben                                                         : Show fewer
# adresse_opdatering_ophort-hjaelp-indhold                                                            : <p>&lt;p&gt;The participant has not had an active affiliation to a company in CVR for three years or more and therefore the address is no longer published in the register. If the participant gets a new active affiliation in the CVR, the address will be published again (unless protected).&lt;/p&gt;<br/>&lt;p&gt;Read more about the options for obtaining addresses that are not published in the CVR.&lt;/p&gt;</p>
# modal-manuel-signering-overskrift                                                                   : Obtain documents with the Danish Business Authority's signature
# modal-manuel-signering-bestil_aabne-broedtekst                                                      : Obtain a paper copy of data from expanded menus on this page. The document has been signed by the Danish Business Authority. The signature confirms the genuineness of the copy. A signature costs DKK 120. Read about prices and delivery.
# modal-manuel-signering-bestil_alt-broedtekst                                                        : Obtain a paper copy of all data on the business. The document has been signed by the Danish Business Authority. The signature confirms the genuineness of the copy. A signature costs DKK 120. Read about prices and delivery.
# bestil_dokumenter-sprogvaelger-dansk-option                                                         : Danish
# bestil_dokumenter-sprogvaelger-engelsk-option                                                       : English
# bestil_dokumenter-navneaendringscertifikat-dato-til-label                                           : To
# bestil_dokumenter-navneaendringscertifikat-dato-seneste-option                                      : Most recent update
# bestil_dokumenter-vedtaegter-dato-seneste-option                                                    : Most recent
# bestil_dokumenter-navneaendringscertifikat-dato-interval-option                                     : Date interval
# bestil_dokumenter-navneaendringscertifikat-dato-fra-label                                           : From
# bestil_dokumenter-navneaendringscertifikat-dato-label                                               : Date interval
# bestil_dokumenter-navneaendringscertifikat-dato-log_ind-indhold                                     : Log in to pick date interval
# bestil_dokumenter-navneaendringscertifikat-dags_dato-label                                          : {0} (today)
# bestil_dokumenter-vedtaegter-dato-interval-option                                                   : Other date
# bestil_dokumenter-vedtaegter-dato-log_ind-indhold                                                   : Log in to pick date
# bestil_dokumenter-vedtaegter-dato-fra-label                                                         : Date
# bestil_dokumenter-vedtaegter-dato-label                                                             : Date
# bestil_dokumenter-bestil-label                                                                      : Order
# bestil_dokumenter-tilfoej_til_kurv-label                                                            : Add to basket
# accordion-bestil_dokumenter-overskrift                                                              : Order other documents (in Danish)
# accordion-hovedselskab-overskrift                                                                   : Information on main company
# virksomhed-hovedselskab-navn                                                                        : Name of main company
# virksomhed-hovedselskab-hjemsted                                                                    : Registered office
# virksomhed-hovedselskab-registerende-myndighed                                                      : Registration authority
# virksomhed-hovedselskab-adresse                                                                     : Address
# virksomhed-hovedselskab-formaal                                                                     : Objects
# virksomhed-hovedselskab-tegnet-kapital                                                              : Subscribed capital
# virksomhed-hovedselskab-tegningsberettiget                                                          : Empowered to sign
# virksomhed-hovedselskab-tegningsregel                                                               : Power to bind
# accordion-hovedselskab-hjaelp-overskrift                                                            : Information on main company
# accordion-hovedselskab-hjaelp-indhold                                                               : <p>&lt;p&gt;Under &quot;Information on main company&quot;, can you read more about name, adress, and purpose with the parent company. You can also read more about subscribed capital, empowered to sign and power to bind&lt;/p&gt;</p>
# virksomhedHovedselskab-fra-label                                                                    : From
# virksomhedHovedselskab-til-label                                                                    : to
# accordion-produktionsenheder-overskrift                                                             : Production units
# registreret_jf_hvidvask                                                                             : Registered cf. the Anti-Money Laundering Act
# stamdata-telefon-label                                                                              : Telephone
# stamdata-reklamebeskyttelse-label                                                                   : Advertising protection
# accordion-produktionsenheder-hjaelp-overskrift                                                      : Production units
# dokumenter-indholdstype-bestil-link                                                                 : Order
# accordion-produktionsenheder-hjaelp-indhold                                                         : <p>&lt;p&gt;P units (production units) refer to the addresses where the business has employees.&lt;br&gt;&lt;br&gt;You must have a P number for each address at which you have employees. The first P number is allocated to you automatically along with your CVR number and it refers to the same address as the CVR number.&lt;/p&gt;</p>
# accordion-produktionsenheder-ophoerte-aaben                                                         : Hide closed production units
# accordion-produktionsenheder-ophoerte-lukket                                                        : Show closed production units
# regnskab-postlevering-modal-offentliggjort-label                                                    : Announced
# regnskab-postlevering-modal-periode-label                                                           : Accounting period
# virksomhedRegistreringer-cvrnummer-label                                                            : CVR number
# virksomhedRegistreringer-adresse-og-navn-label                                                      : Name and adress
# virksomhed-registrering-visalle-lukket                                                              : Show all registrations
# virksomhed-registrering-visalle-aaben                                                               : Show fewer registrations
# accordion-produktionsenheder-aktive-visalle-lukket                                                  : Show all production units
# accordion-produktionsenheder-aktive-visalle-aaben                                                   : Show fewer production units
# modal-branchekode-overskrift                                                                        : Search for a branch
# soeg-branchekode-modal-placeholder                                                                  : The company deals with...
# soeg-branchekode-modal-subtitel                                                                     : Search results
# accordion-branchekode-soegeresultat-rightsideButton-titel                                           : Select
# ejerandel-stemmeretprocent-label                                                                    : Pct. of voting rights:
# accordion-produktionsenheder-ophoerte-visalle-aaben                                                 : Show fewer production units
# accordion-produktionsenheder-ophoerte-visalle-lukket                                                : Show all production units
# broedkrumme-byg-din-egen-virksomhedsrapport                                                         : Create your own business report
# stamdata-pnummer-label                                                                              : P-number
# stamdata-postnummerby-label                                                                         : Postal code and city
# stamdata-regnskabsperiode_for_helligdagsaabent-label                                                : Accounting period for being open on public holidays
# stamdata-aktiviteter_omfattet_af_hvidvaskloven-label                                                : Registered activities cf. the Anti-Money Laundering Act
# stamdata-omfattet_af_hvidvaskloven-label                                                            : Registered cf. the Anti-Money Laundering Act
# accordion-ejerforhold-hjaelp-indhold                                                                : <p>&lt;p&gt;&lt;strong&gt;Legal owners&lt;/strong&gt; are persons or companies that directly:&lt;/p&gt;<br/>&lt;ul&gt;&lt;li&gt;have at least 5% ownership or voting rights&lt;/li&gt;<br/>&lt;/ul&gt;&lt;p&gt;&lt;strong&gt;Beneficial owners&lt;/strong&gt; are persons who directly or indirectly:&lt;/p&gt;<br/>&lt;ul&gt;&lt;li&gt;have more than 25% ownership or voting rights or&lt;/li&gt;<br/>&lt;li&gt;have other decisive control, for example a veto right, the right to appoint Board members or similar&lt;/li&gt;<br/>&lt;/ul&gt;&lt;p&gt;&lt;a href=&quot;https://erhvervsstyrelsen.dk/registrering-af-ejerforhold&quot;&gt;Read more about registration of owners (in Danish)&lt;/a&gt;.&lt;/p&gt;</p>
# ejerforhold-legale-ejere-label                                                                      : Legal owners
# ejerforhold-reelle-ejere-label                                                                      : Beneficial owners
# ejerforhold-ophoerte-legale-ejere-label                                                             : Terminated legal owners
# ejerforhold-ophoerte-reelle-ejere-label                                                             : Terminated beneficial owners
# antal-ansatte-pr-maaned-tabel-label-antalAarsvaerk                                                  : Full-time equivalent
# historisk-stamdata-branchekode-tabel-overskrift                                                     : Activity code
# soeg-branchekode-modal-aria_label                                                                   : Search for a branch
# historisk-stamdata-virksomhedsform-tabel-overskrift                                                 : Business type
# ejerforhold-bestyrelse-anses-som-reelle-ejere-tekst                                                 : The directors of the board are regarded as beneficial owners
# ejerforhold-virksomhed-har-ikke-reelle-ejere-tekst                                                  : The business has no beneficial owners and the management is therefore recognised as the beneficial owners.
# enhedstype-virksomhed-label                                                                         : Businesses {0}
# enhedstype-produktionsenhed-label                                                                   : Production units {0}
# kontekstnaer-hjaelp-aria_label                                                                      : Read more about
# antal-ansatte-pr-maaned-tabel-overskrift                                                            :  Number of employees per month
# historisk-stamdata-virksomhedsform-tabel-label-gyldigFra                                            : From
# historisk-stamdata-branchekode-tabel-label-gyldigFra                                                : From
# historisk-stamdata-virksomhedsform-tabel-label-gyldigTil                                            : Till
# historisk-stamdata-branchekode-tabel-label-gyldigTil                                                : Till
# historisk-stamdata-produktionsenhed-navn-tabel-overskrift                                           : Production unit name
# notfoundpage-header                                                                                 : Page was not found
# notfoundpage-manchet                                                                                : <p>We couldn't find the page you were looking for.<br/>The page may have been moved or there is an error in the URL.</p>
# modal-foelg-virksomhed-overskrift                                                                   : Log in to follow business
# modal-foelg-virksomhed-annuller                                                                     : Cancel
# modal-foelg-virksomhed-godkend                                                                      : OK
# modal-opret-abonnement-overskrift                                                                   : Follow business
# modal-administrer-abonnement-overskrift                                                             : Follow business
# modal-administrer-abonnement-cvr-label                                                              : CVR
# modal-administrer-abonnement-annuller                                                               : Cancel
# modal-administrer-abonnement-godkend                                                                : Follow business
# accordion-virksomhed-historisk-stamdata-overskrift                                                  : Historical basic data
# accordion-virksomhed-historisk-stamdata-hjaelp-indhold                                              : <p>&lt;p&gt;&lt;strong&gt;Historical basic data&lt;/strong&gt;&lt;/p&gt;<br/>&lt;p&gt;Historical basic data shows the history of previous registrations about the business in CVR, e.g. change of name, change of registered address, restructuring, etc.&lt;/p&gt;<br/>&lt;p&gt;The historical data available about the business includes: name, address, activities, business type and status.&lt;/p&gt;</p>
# accordion-virksomhed-historisk-stamdata-hjaelp-overskrift                                           : Historical basic data
# person-liberale_erhverv-deponeringssdato-label                                                      : Date of deposit
# person-liberale_erhverv-deponeringsdato-label                                                       : Date of deposit
# person-liberale_erhverv-mnenummer-label                                                             : Identification
# accordion-oplysninger_om_revisionsvirksomhed-overskrift                                             : Information on audit firm
# oplysninger_om_revisionsvirksomhed-virksomhedstype-label                                            : Type of enterprise
# oplysninger_om_revisionsvirksomhed-startdato-label                                                  : Date of commencement as audit firm
# oplysninger_om_revisionsvirksomhed-kontorsteder-label                                               : Office locations
# oplysninger_om_revisionsvirksomhed-kontorsteder-vis-alle-aaben                                      : Show fewer office locations
# oplysninger_om_revisionsvirksomhed-kontorsteder-vis-alle-lukket                                     : Show all office locations
# oplysninger_om_revisionsvirksomhed-stemmeandel-label                                                : Total percentage of votes held by approved auditors or audit firms
# oplysninger_om_revisionsvirksomhed-kontaktperson-label                                              : Contact person
# oplysninger_om_revisionsvirksomhed-webadresse-label                                                 : Internet address
# oplysninger_om_revisionsvirksomhed-netvaerk-label                                                   : Network
# postnummer-fejlmeddelelse-label                                                                     : Unknown postal code
# virksomhed-gem_som_pdf-label                                                                        : Save as PDF
# person-liberale_erhverv-kontorsteder-label                                                          : Associated office locations
# person-liberale_erhverv-kontorsteder-visalle-lukket                                                 : Show all associations
# person-liberale_erhverv-kontorsteder-visalle-aaben                                                  : Show fewer associations
# simple-person-relationer-overskrift                                                                 : Relations
# simple-person-relationer-cvr                                                                        : CVR-number
# simple-person-relationer-reg                                                                        : Reg-number
# simple-person-relationer-detaljer-lukket                                                            : Show all
# simple-person-relationer-detaljer-aaben                                                             : Show less
# soeg-branchekode-modal-noresults                                                                    : Your search gave no results
# pdf-footer-disclaimer                                                                               : <p>The information in this document is from The Central Business Register (CVR). The data may not be used in any way which suggests that the Danish Business Authority endorses, supports,<br/>recommends or markets the user of the data, or the services or products of the user of the data. The Danish Business Authority is not liable for the content and origin of the data, nor is it liable<br/>for any errors and omissions in the data, including for any loss or damage caused by its use.</p>
# modal-administrer-abonnement-opdater                                                                : Update
# abonnementer-slet-modal-annuller                                                                    : Cancel
# abonnementer-slet-modal-indhold                                                                     : Do you really want to delete the subscription?
# abonnementer-slet_alle-modal-annuller                                                               : Cancel
# abonnementer-slet-modal-overskrift                                                                  : Delete subscription
# abonnementer-slet_alle-modal-overskrift                                                             : Delete all subscriptions
# abonnementer-slet_alle-modal-indhold                                                                : Do you really want to delete all subscriptions?
# abonnementer-slet_alle-label                                                                        : Delete all
# abonnementer-rediger-label                                                                          : Edit
# abonnementer-slet-label                                                                             : Delete
# dokumenter-indholdstype-ukendt                                                                      : Unknown file extension
# produktionsenheder-ophoerte-overskrift                                                              : Closed production units
# modal-download-pdf-gem_aabne_bjaelker-text                                                          : Only save data from expanded menus on this page.
# modal-manuel-signering-gem_alt-text                                                                 : Save all data on the business. The document will be saved as a PDF file with a digital signature from the Danish Business Authority. This service is free of charge.
# modal-manuel-signering-gem_aabne_bjaelker-text                                                      : Only save data from expanded menus on this page. The document will be saved as a PDF file with a digital signature from the Danish Business Authority. This service is free of charge.
# soegeresultat-excel-download-for-mange-del2                                                         :  connections. Please contact the Central Business Register if you want the complete list.
# aktive-relationer-overskrift                                                                        : Active associations
# stamdata-virksomhedsstatus-label                                                                    : Business status
# ophoerte-relationer-aaben                                                                           : Show less
# ophoerte-relationer-lukket                                                                          : Show all
# aktive-relationer-lukket                                                                            : Show all
# aktive-relationer-aaben                                                                             : Show less
# ophoerte-relationer-overskrift                                                                      : Ceased associations
# broedkrumme-bestildokumenter                                                                        : Order documents
# virksomhed-regnskaber-tilbagetrukne-hjaelp-indhold                                                  : <p>The annual report has been withdrawn from publication. It is therefore no longer available.&lt;br/&gt;&lt;br/&gt;<br/>A previously published annual report can for example be withdrawn because:&lt;br/&gt;<br/>&lt;ul&gt;&lt;li&gt;the Danish Business Authority found that it contains such serious errors or omissions that the document is grossly misleading&lt;/li&gt;<br/>&lt;li&gt;the annual report has not been duly approved and audited&lt;/li&gt;<br/>&lt;li&gt;if the same annual report has been reported several times due to a technical error without the report being amended&lt;/li&gt;<br/>&lt;/ul&gt;</p>
# virksomhed-regnskaber-omgjorte-hjaelp-indhold                                                       : <p>The annual report has been amended, and it is therefore no longer relevant. It is possible to retrieve an amended version of the annual report. A published annual report could have been amended for example because:&lt;br/&gt;&lt;br/&gt;<br/>&lt;ul&gt;&lt;li&gt;The company determined that the new annual report is in the interest of the users of the accounts as a necessary correction of significant or obvious errors or rectification of illegal matters.&lt;/li&gt;<br/>&lt;li&gt;The Danish Business Authority found that a submitted annual report is contains significant errors or omissions, and therefore has required the company to submit a corrected annual report.&lt;/li&gt;&lt;/ul&gt;</p>
# virksomhed-regnskaber-omgjorte-hjaelp-overskrift                                                    : Amended annual report
# virksomhed-regnskaber-tilbagetrukne-hjaelp-overskrift                                               : Withdrawn annual report
# udvidede_oplysninger-telefon-label                                                                  : Telephone
# erstdist-organisation-rolle-bestyrelsesmedlemmer                                                    : Board of Directors
# virksomhed-regnskaber-omgjorte-regnskaber-label                                                     : Amended reports
# stamdata-bygningsnummer-label                                                                       : B-number
# oplysninger_om_revisionsvirksomhed-kontorsteder-visalle-lukket                                      : Show all offices
# oplysninger_om_revisionsvirksomhed-kontorsteder-visalle-aaben                                       : Show less offices
# bestil_dokumenter-regnskab_til_postlevering-overskrift                                              : Accounting period: {0}, Announced: {1}
# bestil_dokumenter-sprogvaelger-navneaendringscertifikat-label                                       : Language
# bestil_dokumenter-sprogvaelger-registreringscertifikat-label                                        : Language
# erstdist-saerligeejerforhold-potentielle_kapital_stemmeandele                                       : Potential voting rights {0}
# erstdist-betydeligindflydelseviarolle-er_reel_ejer_som_udpeget_daglig_ledelse                       : Beneficial owners cannot be identified, senior management is registered as beneficial owners {0}
# erstdist-saerligeejerforhold-ret_til_at_udpege_ledelsesmedlemmer                                    : Right to appoint management members {0}
# virksomhed-ret_oplysninger_link                                                                     : Edit business information
# soegeresultater-tabel-matcher-historisk-binavn-hjaelp-indhold                                       : <p>Click on the company to see earlier names for this company under &quot;Udvidet historik eng&quot;.</p>
# soegeresultater-tabel-matcher-historisk-hovednavn-hjaelp-indhold                                    : <p>Click on the company to see earlier names for this company under &quot;Udvidet historik eng&quot;.</p>
# historisk-stamdata-virksomhedsform-tabel-label-vaerdi                                               : Value
# historisk-stamdata-branchekode-tabel-label-vaerdi                                                   : Value
# bestil_dokumenter-generalforsamlingsprotokollat-dato-label                                          : Date
# bestil_dokumenter-generalforsamlingsprotokollat-dato-seneste-option                                 : Most recent
# bestil_dokumenter-generalforsamlingsprotokollat-dato-interval-option                                : Other date
# abonnementer-slet-modal-godkend                                                                     : Cancel subscription
# abonnementer-slet_alle-modal-godkend                                                                : Cancel subscriptions
# abonnementer-slet-alle-tekst                                                                        : Do you wish to cancel all subscriptions ({0})?
# abonnementer-slet-enkelt-tekst                                                                      : Do you wish to stop following:
# abonnementer-slet-enkelt-navn                                                                       : Name:
# abonnementer-slet-enkelt-cvr                                                                        : CVR number:
# abonnementer-slet-enkelt-reg                                                                        : REG number:
# toastr-afmeld-alle-abonnementer-success-notifikation-overskrift                                     : Subscriptions
# toastr-afmeld-abonnement-success-notifikation-overskrift                                            : Subscriptions
# toastr-afmeld-abonnement-success-notifikation-indhold                                               : Subscription was cancelled
# toastr-afmeld-alle-abonnementer-success-notifikation-indhold                                        : Subscriptions were cancelled
# bestil_dokumenter-generalforsamlingsprotokollat-dato-fra-label                                      : Date
# bestil_dokumenter-generalforsamlingsprotokollat-dato-log_ind-indhold                                : Log in to pick date
# toastr-abonnementer-ikke-gyldigt-id-error-notifikation-overskrift                                   : Subscriptions
# toastr-abonnementer-ikke-gyldigt-id-error-notifikation-indhold                                      : Not a valid id
# ...
# artikel-reklamebeskyttelse-overskrift                                                               : Protection against unsolicited advertising
# artikel-bestil_dokumenter-manchet                                                                   : Purchase of documents from CVR requires NemID digital signature which is only available for Danish enterprises and people (entities with a CVR- or CPR-number). We do, however, offer a more manual process for users who cannot get NemID.
# artikel-bestil_dokumenter-overskrift                                                                : How to order certificates and hardcopies
# artikel-byg_din_egen_virksomhedsrapport-overskrift                                                  : Create your own business report
# artikel-byg_din_egen_virksomhedsrapport-manchet                                                     : Combine your own business reports and choose the data to be shown.
# artikel-byg_din_egen_virksomhedsrapport-broedtekst                                                  : <p>&lt;p&gt;For example, if you only need data about registered persons associated with the business and powers to bind, you can choose to have only this data shown.&lt;/p&gt;<br/>&lt;p&gt;This is how you proceed:&lt;/p&gt;<br/>&lt;ol&gt;&lt;li&gt;Go to CVR and search for a business.&lt;/li&gt;<br/>&lt;li&gt;Expand the areas of information you want to include in your report or choose a predefined view in 'Select view'.&lt;/li&gt;<br/>&lt;li&gt;Print the report or save it as a PDF file.&lt;/li&gt;<br/>&lt;/ol&gt;</p><p>&lt;div class=&quot;accordion&quot; overskrift=Download or print the report&quot;&quot;&gt;<br/>&lt;p&gt;You can choose to save the report as a PDF file or to print it. The records page for the individual business in CVR features a 'print' and a 'save' button to the right. You can either print or save all data on the business, or you can print or save the details featuring under individual and expanded menus on the records page for the business. The basic data for the business shown at the top of the page will always be included.&lt;/p&gt;<br/>&lt;/div&gt;</p><p>&lt;div class=&quot;accordion&quot; overskrift=&quot;Get a report with the Danish Business Authority's digital signature&quot;&gt;<br/>&lt;p&gt;If you require confirmation of the authenticity of the report, you can choose to have the report signed digitally. You get a legally valid signature without having to wait for case processing and the post.&lt;/p&gt;<br/>&lt;/div&gt;</p><p>&lt;div class=&quot;accordion&quot; overskrift=&quot;Have physical documents signed&quot;&gt;<br/>&lt;p&gt;You can also order a signature on a physical copy of your report and collect it at our reception or have us send it to you by post. This requires a Danish NemID and the order flow is only available in Danish.&lt;/p&gt;<br/>&lt;/div&gt;</p>
# soegeresultater-alert-ingen_resultater-indhold                                                      : Make sure there are no type errors and that the CVR number does not contain spaces
# virksomhed-regnskaber-tilbagetrukkne-hjaelp-indhold                                                 : <p>The annual report has been withdrawn from publication. It is therefore no longer available.&lt;br/&gt;&lt;br/&gt;</p><p>A previously published annual report can for example be withdrawn because:&lt;br/&gt;</p><p>• the Danish Business Authority found that it contains such serious errors or omissions that the document is grossly misleading&lt;br/&gt;<br/>• the annual report has not been duly approved and audited&lt;br/&gt;<br/>• if the same annual report has been reported several times due to a technical error without the report being amended</p>
# soegeresultater-alert-ingen_resultater-overskrift                                                   : No search results were found
# side-titel-bestildokumenter                                                                         : Order documents
# side-titel-errorpage                                                                                : Page was not found
# antal-ansatte-periode-maaned-2                                                                      : February
# antal-ansatte-periode-maaned-1                                                                      : January
# antal-ansatte-periode-maaned-3                                                                      : March
# antal-ansatte-periode-maaned-4                                                                      : April
# antal-ansatte-periode-maaned-5                                                                      : May
# antal-ansatte-periode-maaned-6                                                                      : June
# antal-ansatte-periode-maaned-7                                                                      : July
# antal-ansatte-periode-maaned-8                                                                      : August
# antal-ansatte-periode-maaned-9                                                                      : September
# antal-ansatte-periode-maaned-10                                                                     : October
# antal-ansatte-periode-maaned-11                                                                     : November
# antal-ansatte-periode-maaned-12                                                                     : December
# eid-login-employee-label                                                                            : Employee from an EU/EEA country using my national digital ID
# eid-login-private-label                                                                             : Private person from an EU/EEA country using my national digital ID
# broedkrumme-eidlogin                                                                                : eID login
# accordion-personkreds-hjaelp-indhold                                                                : <p>&lt;strong&gt;Power to bind the company&lt;/strong&gt; &lt;br/&gt;<br/>The provisions regarding the power to bind the company indicate who may make contracts on behalf of the company.&lt;br/&gt;</p><p>Sole proprietorships and other personally owned companies do not have any such provisions. The persons who bind a personally owned company are always the fully liable partners (or partner).&lt;br/&gt;</p><p>&lt;strong&gt;Fully liable partner&lt;/strong&gt; &lt;br/&gt;<br/>A fully liable partner owns a personally owned company. Some company types have several fully liable partners. They are personally, jointly and severally liable. &lt;br/&gt;</p><p>&lt;strong&gt;Management&lt;/strong&gt; &lt;br/&gt;<br/>The management is responsible for the day-to-day management of the company. If the company is managed by the management alone, the management is also responsible for the overall and strategic management of the company.&lt;br/&gt;</p><p>&lt;strong&gt;Board of Directors&lt;/strong&gt; &lt;br/&gt;<br/>The Board of Directors is responsible for the overall and strategic management of the company. &lt;br/&gt;</p><p>&lt;strong&gt;Supervisory Board&lt;/strong&gt; &lt;br/&gt;<br/>The Supervisory Board may supervise the management if it has been decided not to have a Board of Directors.&lt;br/&gt;</p><p>&lt;strong&gt;Founders&lt;/strong&gt; &lt;br/&gt;</p><p>The founders decided to found the company.&lt;br/&gt;</p><p>&lt;strong&gt;Auditor&lt;/strong&gt; &lt;br/&gt;</p><p>The auditor is the person appointed to audit the company's annual report.</p>
# antal-ansatte-pr-maaned-tabel-label-periode                                                         : Period
# antal-ansatte-pr-maaned-tabel-label-antalAnsatte                                                    : Employees
# ean_nummer-fejlmeddelelse-label                                                                     : EAN number is not valid
# virksomhed-offentliggoerelser-titel                                                                 : Title
# stamdata-tilhoerende_cvrnummer-label                                                                : Related to CVR number
# stamdata-reklamebeskyttelse-link                                                                    : Terms of use
# soeg-filter-virksomhedsstatus-underlikvidation-label                                                : Under liquidation
# forside-soegefelt-filter-virksomhedsform-label                                                      : Business type
# forside-soegefelt-filter-kommune-label                                                              : Municipality
# forside-soegefelt-filter-virksomhedsstatus-label                                                    : Business status
# forside-soegefelt-filter-virksomhedsmarkering-label                                                 : Business marker
# soegeresultater-overskrift                                                                          : We found {0} results
# broedkrumme-soegeresultater                                                                         : Search results
# soegeresultater-tabel-aktive_relationer-label                                                       : Active connections:
# soegeresultater-tabel-virksomhedsform-label                                                         : Business type:
# soegeresultater-tabel-cvrnummer-label                                                               : CVR:
# soegeresultater-tabel-p_nummer-label                                                                : P-number:
# soegeresultater-tabel-regnummer-label                                                               : REG:
# soegeresultater-tabel-aktive_relationer-true-tekst                                                  : Yes
# soegeresultater-tabel-aktive_relationer-false-tekst                                                 : No
# broedkrumme-enhedsvisning                                                                           : Unit View
# stamdata-virksomhedsform-label                                                                      :  Business type
#
# kommunekode                                                            (1578 counts)
# udvidede_oplysninger-kommune-label                                                                  : Municipality
# artikel-saadan_soeger_du-broedtekst                                                                 : <p>&lt;p&gt;There is only one search box in CVR. You can search on CVR number, name of business, city, street name, person, P-number, etc.&lt;/p&gt;</p><p>&lt;div class=&quot;accordion&quot; overskrift=&quot;How to do a search&quot;&gt;<br/>&lt;p&gt;You can search for a specific business by typing the following in the search box in CVR:&lt;/p&gt;<br/>&lt;ul&gt;&lt;li&gt;the name of the business&lt;/li&gt;<br/>&lt;li&gt;the CVR number&lt;/li&gt;<br/>&lt;li&gt;the P number&lt;/li&gt;<br/>&lt;li&gt;names of individuals&lt;/li&gt;<br/>&lt;li&gt;address&lt;/li&gt;<br/>&lt;/ul&gt;<br/>&lt;/div&gt;</p><p>&lt;div class=&quot;accordion&quot; overskrift=&quot;How to do an advanced search&quot;&gt;<br/>&lt;p&gt;&lt;strong&gt;AA/Å&lt;/strong&gt;&lt;br&gt;The search engine will not automatically search for AA and Å as the same letter. It will therefore make a difference whether you search e.g. for 'Århus apotek' or 'Aarhus apotek'. We recommend that you try both combinations when searching for names that can be spelled with either AA or Å.&lt;/p&gt;<br/>&lt;p&gt;An example: Aarhus apotek or Århus apotek&lt;/p&gt;<br/>&lt;p&gt;&lt;strong&gt;Expand your search&lt;/strong&gt;&lt;br&gt;If you are not familiar with the correct or full name of the business, you can insert an asterisk (<em>) at the beginning, middle or end of your search words.&amp;nbsp; This will then expand your search. An example: Dansk super</em>, Søren <em>ristensen, Søren Krist</em>sen&lt;/p&gt;<br/>&lt;p&gt;&lt;strong&gt;Limit your search&lt;/strong&gt;&lt;br&gt;If you want to limit your search you can put quotation marks (” ”) around your search words. This will limit your search. An example: ”Asger Aamund”.&lt;/p&gt;<br/>&lt;p&gt;By using the minus sign (-) in front of a word, you can exclude the word from your search. An example: Københavns kommune –idrætsanlæg&lt;/p&gt;<br/>&lt;p&gt;&lt;strong&gt;Avoid natural language&lt;/strong&gt;&lt;br&gt;The search engine does not understand natural language (such as questions), so you should search for specific businesses, CVR numbers or P-numbers.&lt;/p&gt;<br/>&lt;/div&gt;</p><p>&lt;div class=&quot;accordion&quot; overskrift=&quot;Limit your search with filters&quot;&gt;<br/>&lt;p&gt;To the right, under the search box on the front page of CVR, you can click on 'Filter'.&amp;nbsp; This offers you a number of options:&lt;/p&gt;<br/>&lt;p&gt;&lt;strong&gt;Options for limiting your search&lt;/strong&gt;&lt;br&gt;You can limit your search by business type, business status, number of employees, advertising protection, business markers, municipality, region and role/function (when searching for an individual).&lt;/p&gt;<br/>&lt;p&gt;You can choose to further limit your search with multiple simultaneous filters.&lt;/p&gt;<br/>&lt;p&gt;You can also choose not to search for anything in specific and just filter by for example 'business type' and 'number of employees'. This will allow you to see a list of all companies og a specific type with a specific number of employees.&amp;nbsp;&lt;/p&gt;<br/>&lt;p&gt;&lt;strong&gt;Active and inactive fields&lt;/strong&gt;&lt;br&gt;If you have performed a search and the title on the scrollbar is grey, it is because your search has yielded no results. When the titles are black, they are active.&lt;/p&gt;<br/>&lt;/div&gt;</p>
# forside-soegefelt-filter-kommune-label                                                              : Municipality
#
#
# In total 119 untranslated keys

# %% [markdown]
# ### Now translate the keys using the translation mapping defined above

# %%
def translate_keys(obj, translations: Dict[str, object]):
    ty = type(obj)
    if ty is list:
        return [ translate_keys(obj, translations) for obj in obj ]
    elif ty is dict:
        obj: dict
        res = dict()
        for k, v in obj.items():
            k = translations.get(k, k)
            res[k] = translate_keys(v, translations)
        return res

    elif ty in [str, int, bool, float, type(None)]:
        return obj
    else:
        raise RuntimeError(f"Don't know how to handle type {ty}")

# %%
translated_companies = translate_keys(raw_companies, translations)

# %% [markdown]
# ### Build the schema using `genson`

# %%
schema_builder = SchemaBuilder()
for company in translated_companies:
    schema_builder.add_object(company)

schema = schema_builder.to_schema()

# %% [markdown]
# ### Save the results

# %%
# translations
with open('translations.json', 'w') as f:
    json.dump(translations, f, indent=4)

# %%
# schema
with open('schema.json', 'w') as f:
    json.dump(schema, f, indent=4)

# %%
# translated companies
with open('companies.json', 'w') as f:
    json.dump(translated_companies, f, indent=4)
